# %% [markdown]
# <a href="https://colab.research.google.com/github/kimsun75/dataAnalysis/blob/main/2024_04_24_%EC%A0%95%EC%A0%81%EC%8A%A4%ED%81%AC%EB%A1%A4%EB%A7%81_%EA%B9%80%EC%84%A0make.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
from bs4 import BeautifulSoup

url = 'https://n.news.naver.com/mnews/article/001/0014650694?rc=N&ntype=RANKING'
print(url)

d_list= [ ]
response = requests.get(url)

if response.status_code == 200:
    html = response.text
    soup = BeautifulSoup(html, 'html.parser')
    title = soup.select_one('#title_area > span')
    print(title)
    if title:
        print(f"제목: {title.text}")
        d_list.append({title.text})
    else:
        print("제목을 찾을 수 없습니다.")
else:
    print(response.status_code)
print('----------')

# pandas DataFrame으로 나타내기
import pandas as pd

t_list = []
data = {'title':d_list}
df = pd.DataFrame(data)

df.to_csv('my_naver_news1.csv', index=False) # 파일로 저장하기

df.head()
# Out:
# https://n.news.naver.com/mnews/article/001/0014650694?rc=N&ntype=RANKING
# <span>의대교수 사직 D-1…'찻잔속 태풍' 불과 vs "실제로 사직할 것"</span>
# 제목: 의대교수 사직 D-1…'찻잔속 태풍' 불과 vs "실제로 사직할 것"
# ----------
#                                       title
# 0  {의대교수 사직 D-1…'찻잔속 태풍' 불과 vs "실제로 사직할 것"}
